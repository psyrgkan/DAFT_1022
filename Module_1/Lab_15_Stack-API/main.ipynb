# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
from datetime import datetime
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
fromd = datetime(2022, 9, 18)
tod = datetime(2022, 10, 18)
questions = SITE.fetch('questions', fromdate=fromd, todate=tod)
answers = SITE.fetch('answers', fromdate=fromd, todate=tod)

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 219,
#  'total': 0,
#  'items': [{'tags': ['html', 'node.js', 'apache', 'express', 'fetch-api'],
#    'owner': {'reputation': 1,
#     'user_id': 20257429,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/ALm5wu3wLAFzQya_mU4PmrQDW05nb8tx-T_6wSP1ZPQ=k-s256',
#     'display_name': 'emmac',
#     'link': 'https://stackoverflow.com/users/20257429/emmac'},
#    'is_answered': False,
#    'view_count': 19,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1666095440,
#    'creation_date': 1665945922,
#    'last_edit_date': 1666095440,
#    'question_id': 74089836,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74089836/nodejs-express-post-returns-404-error-on-https-xampp-apache-server-while-proxied',
# ...

# %%
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 214,
#  'total': 0,
#  'items': [{'owner': {'reputation': 76,
#     'user_id': 9465840,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-hwjZOr-BuI0/AAAAAAAAAAI/AAAAAAAAAHA/yIaurRfcZs4/photo.jpg?sz=256',
#     'display_name': 'Rafat Hasan',
#     'link': 'https://stackoverflow.com/users/9465840/rafat-hasan'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1666095369,
#    'last_edit_date': 1666095369,
#    'creation_date': 1666039220,
#    'answer_id': 74103008,
#    'question_id': 74102745,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 76,
#     'user_id': 9465840,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-hwjZOr-BuI0/AAAAAAAAAAI/AAAAAAAAAHA/yIaurRfcZs4/photo.jpg?sz=256',
#     'display_name': 'Rafat Hasan',
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
question = SITE.fetch('questions', fromdate=datetime(2022,10,17), todate=datetime(2022,10,18), min=5, sort='votes', tagged='python')['items'][0]

# %%
print(question)
# Out:
# {'tags': ['python'], 'owner': {'reputation': 2462, 'user_id': 11335032, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/d8a2395b2fa45d4aa621f4e6f500ede7?s=256&d=identicon&r=PG&f=1', 'display_name': 'maxbachmann', 'link': 'https://stackoverflow.com/users/11335032/maxbachmann'}, 'is_answered': True, 'view_count': 361, 'accepted_answer_id': 74098046, 'answer_count': 1, 'score': 12, 'last_activity_date': 1666051248, 'creation_date': 1666012413, 'question_id': 74097901, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/74097901/meaning-of-all-inside-python-class', 'title': 'meaning of `__all__` inside Python class'}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answerswithid = SITE.fetch('answers', ids=[6784, 6473])
answerswithid
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 127,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30453,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
