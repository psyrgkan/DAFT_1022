# %%
import numpy as np
from itertools import permutations, product
from math import comb

# %%
# CHALLENGE 1
perms = [''.join(p) for p in permutations('Ironhack')]
perms
# Out:
# ['Ironhack',
#  'Ironhakc',
#  'Ironhcak',
#  'Ironhcka',
#  'Ironhkac',
#  'Ironhkca',
#  'Ironahck',
#  'Ironahkc',
#  'Ironachk',
#  'Ironackh',
#  'Ironakhc',
#  'Ironakch',
#  'Ironchak',
#  'Ironchka',
#  'Ironcahk',
#  'Ironcakh',
#  'Ironckha',
#  'Ironckah',
#  'Ironkhac',
#  'Ironkhca',
#  'Ironkahc',
#  'Ironkach',
#  'Ironkcha',
#  'Ironkcah',
#  'Irohnack',
#  'Irohnakc',
#  'Irohncak',
#  'Irohncka',
#  'Irohnkac',
#  'Irohnkca',
#  'Irohanck',
#  'Irohankc',
#  'Irohacnk',
#  'Irohackn',
#  'Irohaknc',
#  'Irohakcn',
#  'Irohcnak',
#  'Irohcnka',
#  'Irohcank',
#  'Irohcakn',
#  'Irohckna',
#  'Irohckan',
#  'Irohknac',
#  'Irohknca',
#  'Irohkanc',
#  'Irohkacn',
#  'Irohkcna',
#  'Irohkcan',
#  'Iroanhck',
#  'Iroanhkc',
#  'Iroanchk',
#  'Iroanckh',
#  'Iroankhc',
#  'Iroankch',
#  'Iroahnck',
#  'Iroahnkc',
#  'Iroahcnk',
#  'Iroahckn',
#  'Iroahknc',
#  'Iroahkcn',
#  'Iroacnhk',
#  'Iroacnkh',
#  'Iroachnk',
#  'Iroachkn',
#  'Iroacknh',
#  'Iroackhn',
# ...

# %%
# CHALLENGE 2
comb(17,3)
# Out:
# 680

# %%
# CHALLENGE 3
"""Let's imagine you need to organize the business processes in the coffee shop.  
You know that each cup can be made from 10 possible ingredients. 
But it is not profitable to use more than 5 portions of ingredients at once.
These ingridients should not be unique (for example, you can put milk twice, and a chocolate onle). 
How many different variations of coffee you can include to the menu?
"""
10**5+10**4+10**3+10**2+10
# Out:
# 111110

# %%
# CHALLENGE 4 
"""
Given an array of distinct integers, return all the possible permutations. 
You can return the answer in any order. 
The length of array and the integers are given by user and may vary
"""

def get_perms(given_list):
    return list(permutations(given_list))

# %%
# CHALLENGE 5
"""
Use intertools library to solve the following problem:
Six books are lying on a table in front of you. 
How many ways can you arrange the books, considering both the left-to-right order of the books and whether they're set with the front cover facing up or down?
"""
my_books = 'ABCDEF'
up_down = 'ud'
# perms = [p for p in permutations(product(my_books, up_down))]
# perms

list = []
for c in product(permutations(my_books), product(up_down, repeat=len(my_books))):
    list.append(" ".join(x + y for x,y in zip(*c)))

len(list)
# Out:
# 46080
