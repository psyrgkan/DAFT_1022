# %%
import numpy as np
import pandas as pd

# %%
a = [14, 12, 23, 3]

# %%
s = pd.Series(a)
print(s)
# Out:
# 0    14
# 1    12
# 2    23
# 3     3
# dtype: int64

# %%
s1 = pd.Series(a, index=["day", "month", "year", "people"])
print(s1)
# Out:
# day       14
# month     12
# year      23
# people     3
# dtype: int64

# %%
data = np.random.randint(1, 10, (5, 3, 2))

data = data.reshape(5, 6).T
df = pd.DataFrame(
    data=data,
    index=pd.MultiIndex.from_product([[2015, 2016, 2017], ['US', 'UK']]),
    columns=['item {}'.format(i) for i in range(1, 6)]
)

# %%
print(df)
# Out:
#          item 1  item 2  item 3  item 4  item 5
# 2015 US       3       8       7       5       1
#      UK       5       5       6       5       5
# 2016 US       1       4       2       3       5
#      UK       5       1       1       4       7
# 2017 US       4       4       8       3       8
#      UK       5       5       4       9       5

# %%
l = [(1, 2, 3)]
df = pd.DataFrame(l)
print(df)
# Out:
#    0  1  2
# 0  1  2  3

# %%
file1 = pd.read_csv(r'./file1.csv')
file1
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
file1.shape
# Out:
# (1007, 17)

# %%
file1.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
file1.dtypes
# Out:
# CONTROLN      int64
# STATE        object
# GENDER       object
# HV1          object
# IC1           int64
# IC4         float64
# HVP1          int64
# IC5          object
# POBC1         int64
# POBC2         int64
# IC2         float64
# IC3           int64
# AVGGIFT     float64
# TCODE         int64
# DOB           int64
# DOMAIN       object
# TARGET_D    float64
# dtype: object

# %%
file1["STATE"].tail(5)
# Out:
# 1002    OK
# 1003    CA
# 1004    IA
# 1005    WA
# 1006    FL
# Name: STATE, dtype: object

# %%
file1.describe()
# Out:
#             CONTROLN          IC1          IC4         HVP1        POBC1  \
# count    1007.000000  1007.000000  1006.000000  1007.000000  1007.000000
# mean    98913.029791   352.015889   445.059642    16.261172     6.847071
# std     58306.879885   173.937638   178.115476    29.464477     9.333689
# min        71.000000     0.000000     0.000000     0.000000     0.000000
# 25%     44930.500000   238.500000   325.000000     0.000000     1.000000
# 50%    101113.000000   319.000000   406.000000     1.000000     4.000000
# 75%    151559.000000   421.500000   527.000000    14.000000     9.000000
# max    191779.000000  1500.000000  1263.000000    99.000000    73.000000
#
#              POBC2          IC2          IC3      AVGGIFT        TCODE  \
# count  1007.000000  1006.000000  1007.000000  1007.000000  1007.000000
# mean     55.630586   401.658052   400.022840    11.863404    37.747766
# std      21.593999   182.024618   168.901139     7.829965   213.010617
# ...

# %%
file1.loc[1:6]
# Out:
#    CONTROLN STATE  GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 1     96093    IL       M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL       F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC       M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL       F   995.00  252  348.0     0  17991      5      6
# 5    100640    IL       M   764.00  457  501.0     1  16022      2     75
# 6     18581    NC  female   775.00  318  419.0     5  13491      0     73
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0
# 5  477.0  480  25.571429      1  6104     S2      30.0
# 6  364.0  380   4.625000      0  4407     R2      12.0

# %%
file1[(file1.STATE == 'FL') & (file1.DOMAIN == 'C3')]
# Out:
#      CONTROLN STATE GENDER   HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 101     37472    FL      M   825  233  301.0     0   9747     63     21
# 306     35476    FL      M   625  259  309.0     0  11072     17     16
# 454     39935    FL      M  1464  305  472.0     7  22648     11     13
# 510     44853    FL      M   578  246  323.0     0  14121      3     13
# 580     45503    FL      M   616  212  282.0     1  11912      5     16
# 603     42096    FL      F   355  208  244.0     0   9881      5     34
# 627     45666    FL      F   566  218  272.0     0  11438      9      8
#
#        IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 101  239.0  290  20.000000      1     0     C3      20.0
# 306  282.0  299  17.142857      1  3609     C3      25.0
# 454  413.0  377   4.000000      0  6001     C3       4.0
# 510  323.0  275  10.642857      1  2912     C3      12.0
# 580  234.0  248   5.133333      1  3709     C3       5.0
# ...

# %%
file2 = file1.copy()

# %%
del file2["STATE"]

# %%
file1
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
file2
# Out:
#       CONTROLN GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2     IC2  \
# 0        44060      M   AAA896  392  520.0     7  21975      6     16   430.0
# 1        96093      M   537.00  365  473.0     0  19387      1     89   415.0
# 2        43333      F   725.00  301  436.0     3  18837     11     17   340.0
# 3        21885      M  AAA1095  401  413.0     7  14014      1     74   407.0
# 4       190108      F   995.00  252  348.0     0  17991      5      6   280.0
# ...        ...    ...      ...  ...    ...   ...    ...    ...    ...     ...
# 1002    114721    NaN     1040  472  656.0     0  26962      2     56   609.0
# 1003    149152      M     4507  842  962.0    95  54642     17     50  1004.0
# 1004       959      F      586  349  465.0     1  15304      1     77   413.0
# 1005    179563   male      842  420  494.0     2  12894     41     24   419.0
# 1006     41243      F      556  246  330.0     0  10272      2     56   277.0
#
# ...

# %%
vehicles = pd.read_csv(r"/Users/tinym/Downloads/vehicles/vehicles.csv")
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
vehicles = vehicles.rename(columns = {'Make': 'Producer', 'Engine Displacement': 'Displacement'})

# %%
column_order = ['Year','Vehicle Class','Transmission','Drivetrain','Fuel Type',
                'Cylinders','Displacement','Fuel Barrels/Year',
                'City MPG','Highway MPG','Combined MPG',
                'CO2 Emission Grams/Mile','Fuel Cost/Year']

vehicles = vehicles[column_order]

# %%
filtered = vehicles[(vehicles['Fuel Type']=='Regular') & (vehicles['Cylinders']>=6) & (vehicles['Fuel Cost/Year'] < 2000)]

filtered.head()
# Out:
#     Year    Vehicle Class     Transmission         Drivetrain Fuel Type  \
# 7   1997  Subcompact Cars  Automatic 4-spd  Front-Wheel Drive   Regular
# 10  1998  Subcompact Cars  Automatic 4-spd  Front-Wheel Drive   Regular
# 13  1999  Subcompact Cars  Automatic 4-spd  Front-Wheel Drive   Regular
# 91  1986     Compact Cars  Automatic 4-spd  Front-Wheel Drive   Regular
# 92  1986     Compact Cars     Manual 5-spd  Front-Wheel Drive   Regular
#
#     Cylinders  Displacement  Fuel Barrels/Year  City MPG  Highway MPG  \
# 7         6.0           3.0          16.480500        18           26
# 10        6.0           3.0          16.480500        17           26
# 13        6.0           3.0          16.480500        17           26
# 91        6.0           2.5          17.347895        17           22
# 92        6.0           2.5          16.480500        18           23
#
#     Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %%
avg_mpg = vehicles.groupby('Fuel Type', as_index=False).agg({'Combined MPG':'mean'})
avg_mpg.columns = ['Fuel Type', 'Avg_MPG']
avg_mpg
# Out:
#                       Fuel Type    Avg_MPG
# 0                           CNG  18.133333
# 1                        Diesel  23.488474
# 2               Gasoline or E85  17.572385
# 3       Gasoline or natural gas  15.350000
# 4           Gasoline or propane  13.500000
# 5                      Midgrade  17.378378
# 6                       Premium  19.343816
# 7    Premium Gas or Electricity  31.647059
# 8       Premium and Electricity  26.300000
# 9                Premium or E85  20.090909
# 10                      Regular  20.144698
# 11  Regular Gas and Electricity  41.937500
# 12   Regular Gas or Electricity  42.000000
